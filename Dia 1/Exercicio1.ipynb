# %% [markdown]
# **Importando tabela**

# %%
import pandas as pd
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-ff8d290d-aa04-4d46-98c8-a511293cebb8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff8d290d-aa04-4d46-98c8-a511293cebb8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving exercicio1.xlsx to exercicio1.xlsx

# %%
olimpiadas_df = pd.read_excel('exercicio1.xlsx')

# %%
olimpiadas_df
# Out:
#           City  Edition  ... Event_gender   Medal
# 0       Athens     1896  ...            M    Gold
# 1       Athens     1896  ...            M  Silver
# 2       Athens     1896  ...            M  Bronze
# 3       Athens     1896  ...            M    Gold
# 4       Athens     1896  ...            M  Silver
# ...        ...      ...  ...          ...     ...
# 29211  Beijing     2008  ...            M  Silver
# 29212  Beijing     2008  ...            M  Bronze
# 29213  Beijing     2008  ...            M  Bronze
# 29214  Beijing     2008  ...            M    Gold
# 29215  Beijing     2008  ...            M  Silver
#
# [29216 rows x 10 columns]

# %% [markdown]
# **Verifica se há nulls**

# %%
olimpiadas_df.isna().mean()*100

# %% [markdown]
# **Vendo qual modalidade tem mais frequencia - resposta para o exercício 1**

# %%
olimpiadas_df.Discipline.value_counts()

# %% [markdown]
# **Vendo qual atleta ganhou mais medalhas - resposta para o exercício 2**

# %%
olimpiadas_df.Athlete.value_counts()[:10]
# Out:
# LATYNINA, Larisa        18
# PHELPS, Michael         16
# ANDRIANOV, Nikolay      15
# MANGIAROTTI, Edoardo    13
# ONO, Takashi            13
# SHAKHLIN, Boris         13
# THOMPSON, Jenny         12
# TORRES, Dara            12
# NURMI, Paavo            12
# FISCHER, Birgit         12
# Name: Athlete, dtype: int64

# %% [markdown]
# **Calculando a soma da quantidade de medalhas - resposta para o exercício 3**

# %%
soma = olimpiadas_df.Medal.value_counts().sum()
soma
# Out:
# 29216
